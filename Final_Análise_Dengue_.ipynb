# %% [markdown]
# # **Dengue Brasil**

# %% [markdown]
# # **Indrodução**

# %% [markdown]
# A dengue faz parte de um grupo de doenças denominadas arboviroses, que se caracterizam por serem causadas por vírus transmitidos por vetores artrópodes. No Brasil, o vetor da dengue é a fêmea do mosquito Aedes aegypti (significa "odioso do Egito"). Os vírus dengue (DENV) estão classificados cientificamente na família Flaviviridae e no gênero Orthoflavivirus. Até o momento são conhecidos quatro sorotipos – DENV-1, DENV-2, DENV-3 e DENV-4 –, que apresentam distintos materiais genéticos (genótipos) e linhagens.
#
# Mosquito se alimentando
# As evidências apontam que o mosquito tenha vindo nos navios que partiam da África com escravos. No Brasil, a primeira epidemia documentada clínica e laboratorialmente ocorreu em 1981-1982, em Boa Vista (RR), causada pelos sorotipos 1 e 4. Após quatro anos, em 1986, ocorreram epidemias atingindo o estado do Rio de Janeiro e algumas capitais da região Nordeste. Desde então, a dengue vem ocorrendo de forma continuada (endêmica), intercalando-se com a ocorrência de epidemias, geralmente associadas à introdução de novos sorotipos em áreas indenes (sem transmissão) e/ou alteração do sorotipo predominante, acompanhando a expansão do mosquito vetor.
#
# Aspectos como a urbanização, o crescimento desordenado da população, o saneamento básico deficitário e os fatores climáticos mantêm as condições favoráveis para a presença do vetor, com reflexos na dinâmica de transmissão desses arbovírus. A dengue possui padrão sazonal, com aumento do número de casos e o risco para epidemias, principalmente entre os meses de outubro de um ano a maio do ano seguinte.
#
# Todas as faixas etárias são igualmente suscetíveis à doença, porém as pessoas mais velhas e aquelas que possuem doenças crônicas, como diabetes e hipertensão arterial, têm maior risco de evoluir para casos graves e outras complicações que podem levar à morte.

# %% [markdown]
# # **Sinais e sintomas**

# %% [markdown]
# A dengue é uma doença febril aguda, sistêmica, dinâmica, debilitante e autolimitada. A maioria dos doentes se recupera, porém, parte deles podem progredir para formas graves, inclusive virem a óbito. A quase totalidade dos óbitos por dengue é evitável e depende, na maioria das vezes, da qualidade da assistência prestada e organização da rede de serviços de saúde.
#
# Todo indivíduo que apresentar febre (39°C a 40°C) de início repentino e apresentar pelo menos duas das seguintes manifestações - dor de cabeça, prostração, dores musculares e/ou articulares e dor atrás dos olhos – deve procurar imediatamente um serviço de saúde, a fim de obter tratamento oportuno.

# %% [markdown]
# #**Link Ministério da Saúde**
#
# Base de Dados da MS: http://tabnet.datasus.gov.br/cgi/deftohtm.exe?sinannet/cnv/denguebr.def
#
# Documentos importantes: http://tabnet.datasus.gov.br/tabdata/LivroIDB/2edrev/d0203.pdf

# %% [markdown]
# *   Importação das Bibliotecas.

# %%
# Manipulação de dados.
import pandas as pd
import numpy as np

# Visualização dos dados.
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# *   Carregamento da base de dados.

# %%
file_name = '/content/drive/MyDrive/00 - Colab Notebooks/Análise Dengue /Base de Dados Dengue.xlsx'

df = pd.read_excel(file_name)

# %% [markdown]
# *   Limpeza dos dados - remoção de espaços em branco em campos textuais.

# %%
df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# /tmp/ipython-input-8-2331361843.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#                     municipio  uf data_infeccoes  qtd_infeccoes
# 0       ALTA FLORESTA D'OESTE  RO     2013-01-01             34
# 1       ALTA FLORESTA D'OESTE  RO     2013-02-01             44
# 2       ALTA FLORESTA D'OESTE  RO     2013-03-01             15
# 3       ALTA FLORESTA D'OESTE  RO     2013-04-01              4
# 4       ALTA FLORESTA D'OESTE  RO     2013-05-01              3
# ...                       ...  ..            ...            ...
# 728767               BRASILIA  DF     2023-08-01            939
# 728768               BRASILIA  DF     2023-09-01            843
# 728769               BRASILIA  DF     2023-10-01            686
# 728770               BRASILIA  DF     2023-11-01           1300
# 728771               BRASILIA  DF     2023-12-01           5603
#
# ...

# %% [markdown]
# *   Inspeção inicial - visualizando o tamanho do dataset.

# %%
print(f"---------------------------------------\n Tamanho do nosso Dataset: {df.shape}.\n---------------------------------------")
# Out:
# ---------------------------------------
#  Tamanho do nosso Dataset: (728772, 4).
# ---------------------------------------

# %% [markdown]
# *   Verificação dos tipos de dados de cada coluna.

# %%
df.dtypes
# Out:
# municipio                 object
# uf                        object
# data_infeccoes    datetime64[ns]
# qtd_infeccoes              int64
# dtype: object

# %% [markdown]
# *   Inspeção geral - estrutura, tipos de dados e valores não nulos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728772 entries, 0 to 728771
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   municipio       728772 non-null  object
#  1   uf              728772 non-null  object
#  2   data_infeccoes  728772 non-null  datetime64[ns]
#  3   qtd_infeccoes   728772 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 22.2+ MB

# %% [markdown]
# *   Verificação de valores nulos no dataset.

# %%
df.isnull()
# Out:
#         municipio     uf  data_infeccoes  qtd_infeccoes
# 0           False  False           False          False
# 1           False  False           False          False
# 2           False  False           False          False
# 3           False  False           False          False
# 4           False  False           False          False
# ...           ...    ...             ...            ...
# 728767      False  False           False          False
# 728768      False  False           False          False
# 728769      False  False           False          False
# 728770      False  False           False          False
# 728771      False  False           False          False
#
# [728772 rows x 4 columns]

# %% [markdown]
# *   Contagem de valores nulos por coluna.

# %%
df.isnull().sum()
# Out:
# municipio         0
# uf                0
# data_infeccoes    0
# qtd_infeccoes     0
# dtype: int64

# %% [markdown]
# *   Contagem total de valores nulos no DataFrame.

# %%
print(f"O DataFrame possui: {df.isnull().sum().sum()} dados nulos")
# Out:
# O DataFrame possui: 0 dados nulos

# %% [markdown]
# *   Contagem de valores únicos por coluna.

# %%
df.nunique()
# Out:
# municipio         5243
# uf                  27
# data_infeccoes     132
# qtd_infeccoes     1157
# dtype: int64

# %% [markdown]
# *   Criar uma nova coluna Ano, usando os dados da coluna data_infeccao.

# %%
df ["Ano"] = df["data_infeccoes"].dt.year
df.head()
# Out:
#                municipio  uf data_infeccoes  qtd_infeccoes   Ano
# 0  ALTA FLORESTA D'OESTE  RO     2013-01-01             34  2013
# 1  ALTA FLORESTA D'OESTE  RO     2013-02-01             44  2013
# 2  ALTA FLORESTA D'OESTE  RO     2013-03-01             15  2013
# 3  ALTA FLORESTA D'OESTE  RO     2013-04-01              4  2013
# 4  ALTA FLORESTA D'OESTE  RO     2013-05-01              3  2013

# %% [markdown]
# *   Agrupamento e soma das infecções por Ano, Município e UF.

# %%
infeccoes_municipio = df.groupby(["Ano",'municipio',"uf"])['qtd_infeccoes'].sum().reset_index()
infeccoes_municipio.head()
# Out:
#     Ano            municipio  uf  qtd_infeccoes
# 0  2013      ABADIA DE GOIAS  GO             52
# 1  2013  ABADIA DOS DOURADOS  MG              0
# 2  2013            ABADIANIA  GO             37
# 3  2013               ABAETE  MG            486
# 4  2013           ABAETETUBA  PA             15

# %% [markdown]
# *   Agrupamento e soma das infecções por Ano e UF.

# %%
infeccoes_estado = df.groupby(["Ano", "uf"])['qtd_infeccoes'].sum().reset_index()
infeccoes_estado
# Out:
#       Ano  uf  qtd_infeccoes
# 0    2013  AC           1663
# 1    2013  AL            704
# 2    2013  AM           4327
# 3    2013  AP            546
# 4    2013  BA          13417
# ..    ...  ..            ...
# 292  2023  RS          27389
# 293  2023  SC          77954
# 294  2023  SE           1749
# 295  2023  SP         198774
# 296  2023  TO           1232
#
# [297 rows x 3 columns]

# %% [markdown]
# *   Análise estatística descritiva das infecções por estado.

# %%
df = pd.DataFrame(infeccoes_estado)
df['qtd_infeccoes'].describe()
df.qtd_infeccoes.describe()
# Out:
# count       297.000000
# mean      12872.474747
# std       31630.107741
# min           0.000000
# 25%         780.000000
# 50%        2229.000000
# 75%       10098.000000
# max      286000.000000
# Name: qtd_infeccoes, dtype: float64

# %% [markdown]
#  **Interpretação**
#
# Os dados referem-se a 297 registros de infecções distribuídos entre os anos de 2013 a 2023. A média de infecções por registro é de aproximadamente 12.872 casos, com alta variação (desvio padrão de 31.630), o que indica desigualdade nos valores. A mediana é de 2.229, sugerindo que mais da metade dos registros têm valores bem abaixo da média, evidenciando a presença de grandes picos. O valor máximo é 286.000 infecções, enquanto o mínimo é zero, o que reforça a existência de outliers significativos no conjunto. Esses dados mostram uma distribuição assimétrica, com concentração em valores baixos e poucos registros com números extremamente altos.

# %% [markdown]
# *   Visualização da distribuição de infecções por UF usando gráfico de Boxplot (2013 - 2023).

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=infeccoes_estado, x="uf", y="qtd_infeccoes", palette= "Set2")

plt.title("Distribuição de Quantidade de Infecções por UF (2013 - 2023)")
plt.xlabel("uf")
plt.ylabel("Quantidade de Infecções")
plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.show()
# Out:
# /tmp/ipython-input-33-2538428863.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=infeccoes_estado, x="uf", y="qtd_infeccoes", palette= "Set2")

# %% [markdown]
#  **Interpretação**
#
# O gráfico boxplot da quantidade de infecções por UF entre 2013 e 2023 revela uma forte desigualdade na distribuição das infecções entre os estados brasileiros. São Paulo se destaca com a maior mediana e a maior variabilidade nos dados, seguido por Minas Gerais, que também apresenta alto volume e oscilação significativa.
# Por outro lado, estados com menor população, registram medianas baixas e pouca variação, indicando uma situação epidemiológica mais estável. A presença de outliers em diversos estados sugere a ocorrência de anos pontuais com surtos ou picos anormais de infecção. Esses padrões reforçam a importância de estratégias regionais na gestão da saúde pública.

# %% [markdown]
# *   Visualização da distribuição de infecções por Ano usando gráfico de Boxplot.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=infeccoes_estado, x="Ano", y="qtd_infeccoes", palette= "Set2")

plt.title("Distribuição de Quantidade de Infecções por Ano")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Infecções")
plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.show()
# Out:
# /tmp/ipython-input-34-1856039450.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=infeccoes_estado, x="Ano", y="qtd_infeccoes", palette= "Set2")

# %% [markdown]
#  **Interpretação**
#
# O gráfico boxplot apresenta a distribuição das infecções por ano, evidenciando uma grande variabilidade na quantidade de casos confirmados. A presença de outliers demonstra períodos em que houve surtos de grande escala, o que reforça a necessidade de um monitoramento contínuo. Os picos de infecções provavelmente coincidem com eventos climáticos favoráveis à proliferação do mosquito, como temporadas de chuvas intensas.

# %% [markdown]
# *   Visualização da distribuição de infecções no ano 2023 usando gráfico de Boxplot.

# %%
infeccoes_2023 = infeccoes_estado[infeccoes_estado['Ano'] == 2023]

plt.figure(figsize=(10, 6))
sns.boxplot(data=infeccoes_2023, x="Ano", y="qtd_infeccoes")
plt.title("Distribuição de Quantidade de Infecções - Ano 2023")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Infecções")
plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.show()

# %% [markdown]
#  **Interpretação**
#
# A visualização indica que a maior parte dos estados teve registros de infecções concentrados em valores relativamente baixos, com a mediana de 12.872,47 casos. No entanto, o gráfico também revela a presença de outliers significativos, ou seja, estados que tiveram quantidades de infecção muito acima do padrão observado na maioria dos casos. Três desses outliers ultrapassam a marca de 75.000, chegando até proximo a 200.000 infecções, o que sugere que alguns estados enfrentaram surtos mais severos ou maior incidência da doença em 2023.
# Além disso, a caixa (interquartil) é assimétrica e está mais próxima da base do gráfico, evidenciando uma distribuição desigual e assimétrica, com concentração de valores baixos e poucos registros com números extremamente altos. Esses dados indicam que, embora a maioria dos estados tenha registrado números controlados, uma minoria significativa puxou a média para cima, exigindo atenção especial em análises regionais.

# %% [markdown]
# *   Organização das quantidades de infectados por ordem decrescente no ano 2023.

# %%
infeccoes_2023 = infeccoes_2023.sort_values(by="qtd_infeccoes", ascending=False)
infeccoes_2023
# Out:
#       Ano  uf  qtd_infeccoes
# 295  2023  SP         198774
# 280  2023  MG         106923
# 293  2023  SC          77954
# 287  2023  PR          48328
# 288  2023  RJ          27905
# 292  2023  RS          27389
# 276  2023  DF          23710
# 278  2023  GO          21682
# 281  2023  MS          21098
# 282  2023  MT          19356
# 274  2023  BA          13249
# 290  2023  RO           7904
# 275  2023  CE           7437
# 272  2023  AM           3263
# 283  2023  PA           2607
# 279  2023  MA           2428
# 270  2023  AC           1781
# 294  2023  SE           1749
# 296  2023  TO           1232
# 284  2023  PB            746
# 273  2023  AP            742
# 285  2023  PE            680
# 271  2023  AL            473
# 286  2023  PI            431
# 289  2023  RN            355
# 291  2023  RR            182
# 277  2023  ES              0

# %% [markdown]
# *   Visualização da distribuição em ordem decrescente de infecções por estado em 2023 usando gráfico de barras.

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = infeccoes_2023, x = "uf", y = "qtd_infeccoes", palette = "Set2")
plt.title("Distribuição de Quantidade de Infecções - 2023")
plt.xlabel("Estados")
plt.ylabel("Quantidade de Infecções")
plt.tick_params(axis='x', rotation=45)
plt.grid(axis = "y", linestyle = "--", alpha = 0.7)
plt.show()
# Out:
# /tmp/ipython-input-25-4277981518.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = infeccoes_2023, x = "uf", y = "qtd_infeccoes", palette = "Set2")

# %% [markdown]
#  **Interpretação**
#
# O gráfico de barras apresentado mostra a distribuição da quantidade de infecções por estado brasileiro no ano de 2023. A visualização revela uma grande desigualdade regional no número de infecções. O estado de São Paulo (SP) lidera com ampla margem, chegando próximo de 200 mil casos, seguido por Minas Gerais (MG) e Santa Catarina (SC), que também registram números expressivos (acima de 75 mil).
#
# Na sequência, estados como Paraná (PR), Rio de Janeiro (RJ) e Rio Grande do Sul (RS) apresentam valores intermediários, enquanto a maioria dos demais estados apresenta quantidades consideravelmente mais baixas. Alguns estados, como Espírito Santo (ES), Roraima (RR) e Rio Grande do Norte (RN), têm números quase insignificantes em comparação aos demais.
#
# Essa distribuição indica que os estados mais populosos e urbanizados concentraram a maior parte dos casos, enquanto os estados menores, com menor densidade demográfica, apresentaram números mais baixos. O gráfico reforça a importância de considerar o contexto populacional e estrutural de cada estado na análise e no planejamento de ações de saúde pública.

# %% [markdown]
# *   Visualização da tendência temporal de infecções com gráfico de dispersão e linha de regressão (2013 - 2023).

# %%
plt.figure(figsize=(12,6))
sns.regplot(data = infeccoes_estado, x = "Ano", y = "qtd_infeccoes", scatter = {"s":15}, line_kws={"color": "red"})
plt.title("Distribuição de Quantidade de Infecções")
plt.xlabel("Ano")
plt.ylabel("Quantidade de Infecções")
plt.grid(linestyle = "--")
plt.show()

# %% [markdown]
#  **Interpretação**
#
# O gráfico apresentado é um gráfico de dispersão com linha de regressão, que mostra a evolução da quantidade de infecções por ano entre 2013 e 2023. Cada ponto azul representa o número de infecções registrado em um estado em determinado ano, e a linha vermelha indica a tendência média ao longo do tempo.
# A distribuição dos pontos mostra que, embora a maioria dos registros de infecções esteja concentrada em valores baixos (abaixo de 50 mil), há diversos outliers (valores isoladamente altos), especialmente nos anos de 2015, 2019, 2022 e 2023, em que alguns estados ultrapassaram 150 mil infecções em um único ano.
# A linha de regressão levemente inclinada para cima indica uma tendência crescente no número médio de infecções ao longo do período, sugerindo que, apesar da alta variabilidade anual e das discrepâncias entre estados, o total de infecções tende a aumentar com o passar dos anos. Essa tendência pode refletir fatores como crescimento populacional, mudanças nos padrões epidemiológicos, condições climáticas favoráveis, falhas no controle vetorial e na vigilância epidemiológica.
